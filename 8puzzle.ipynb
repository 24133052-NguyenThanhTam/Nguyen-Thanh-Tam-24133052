# %%
import random
def tim_o_trong(ma_tran):
    for i in range(3):
        for j in range(3):
            if ma_tran[i][j] == 0:
                return i, j
def luat(x, y):
    if x == 0 and y == 0:
        return ["phai", "xuong"]
    elif x == 1 and y == 0:
        return ["len", "phai", "xuong"]
    elif x == 2 and y == 0:
        return ["len", "phai"]
    elif x == 0 and y == 1:
        return ["trai", "phai", "xuong"]
    elif x == 1 and y == 1:
        return ["len", "xuong", "trai", "phai"]
    elif x == 2 and y == 1:
        return ["len", "trai", "phai"]
    elif x == 1 and y == 2:
        return ["len", "trai", "xuong"]
    elif x == 0 and y == 2:
        return ["trai", "xuong"]
    elif x == 2 and y == 2:
        return ["len", "trai"]
def action(ma_tran):
    x, y = tim_o_trong(ma_tran)
    hanh_dong = luat(x, y)
    return random.choice(hanh_dong)

MA_TRAN = [
    [1,2,3],
    [4,5,6],
    [0,7,8]
]
KETQUA = [
    [1,2,3],
    [4,5,6],
    [7,8,0]
]
SO_LAN = 0
while ((MA_TRAN != KETQUA) and (SO_LAN < 100)):
    SO_LAN += 1
    (x, y) = tim_o_trong(MA_TRAN)
    HUONG_DI = action(MA_TRAN)
    print("hanh dong lan ",SO_LAN, ": di", HUONG_DI)
    if(HUONG_DI == "len"):
        MA_TRAN[x][y], MA_TRAN[x-1][y] = MA_TRAN[x-1][y], MA_TRAN[x][y]
    elif(HUONG_DI == "xuong"):
            MA_TRAN[x][y], MA_TRAN[x+1][y] = MA_TRAN[x+1][y], MA_TRAN[x][y]
    elif(HUONG_DI == "trai"):     
        MA_TRAN[x][y], MA_TRAN[x][y-1] = MA_TRAN[x][y-1], MA_TRAN[x][y]
    elif(HUONG_DI == "phai"):    
        MA_TRAN[x][y], MA_TRAN[x][y+1] = MA_TRAN[x][y+1], MA_TRAN[x][y]
    print("ma tran sau khi di chuyen: ", MA_TRAN)
    if(SO_LAN == 100):
        print("Da dat toi so lan cho phep, ket thuc chuong trinh")
# Out:
# hanh dong lan  1 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 5, 6], [4, 7, 8]]
# hanh dong lan  2 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 5, 6], [0, 7, 8]]
# hanh dong lan  3 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 5, 6], [4, 7, 8]]
# hanh dong lan  4 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 5, 6], [0, 7, 8]]
# hanh dong lan  5 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 5, 6], [7, 0, 8]]
# hanh dong lan  6 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 6], [7, 5, 8]]
# hanh dong lan  7 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 4, 6], [7, 5, 8]]
# hanh dong lan  8 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [0, 5, 8]]
# hanh dong lan  9 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 4, 6], [7, 5, 8]]
# hanh dong lan  10 : di len
# ma tran sau khi di chuyen:  [[0, 2, 3], [1, 4, 6], [7, 5, 8]]
# hanh dong lan  11 : di phai
# ma tran sau khi di chuyen:  [[2, 0, 3], [1, 4, 6], [7, 5, 8]]
# hanh dong lan  12 : di trai
# ma tran sau khi di chuyen:  [[0, 2, 3], [1, 4, 6], [7, 5, 8]]
# hanh dong lan  13 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 4, 6], [7, 5, 8]]
# hanh dong lan  14 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [0, 5, 8]]
# hanh dong lan  15 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [5, 0, 8]]
# hanh dong lan  16 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [0, 5, 8]]
# hanh dong lan  17 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [5, 0, 8]]
# hanh dong lan  18 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [0, 5, 8]]
# hanh dong lan  19 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 4, 6], [7, 5, 8]]
# hanh dong lan  20 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [0, 5, 8]]
# hanh dong lan  21 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [5, 0, 8]]
# hanh dong lan  22 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [0, 5, 8]]
# hanh dong lan  23 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [5, 0, 8]]
# hanh dong lan  24 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 0, 6], [5, 4, 8]]
# hanh dong lan  25 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [5, 0, 8]]
# hanh dong lan  26 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [0, 5, 8]]
# hanh dong lan  27 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 4, 6], [7, 5, 8]]
# hanh dong lan  28 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [7, 4, 6], [0, 5, 8]]
# hanh dong lan  29 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 4, 6], [7, 5, 8]]
# hanh dong lan  30 : di len
# ma tran sau khi di chuyen:  [[0, 2, 3], [1, 4, 6], [7, 5, 8]]
# hanh dong lan  31 : di phai
# ma tran sau khi di chuyen:  [[2, 0, 3], [1, 4, 6], [7, 5, 8]]
# hanh dong lan  32 : di trai
# ma tran sau khi di chuyen:  [[0, 2, 3], [1, 4, 6], [7, 5, 8]]
# hanh dong lan  33 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 4, 6], [7, 5, 8]]
# hanh dong lan  34 : di len
# ma tran sau khi di chuyen:  [[0, 2, 3], [1, 4, 6], [7, 5, 8]]
# hanh dong lan  35 : di phai
# ma tran sau khi di chuyen:  [[2, 0, 3], [1, 4, 6], [7, 5, 8]]
# hanh dong lan  36 : di trai
# ma tran sau khi di chuyen:  [[0, 2, 3], [1, 4, 6], [7, 5, 8]]
# hanh dong lan  37 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 4, 6], [7, 5, 8]]
# hanh dong lan  38 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 6], [7, 5, 8]]
# hanh dong lan  39 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 0], [7, 5, 8]]
# hanh dong lan  40 : di len
# ma tran sau khi di chuyen:  [[1, 2, 0], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  41 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 0], [7, 5, 8]]
# hanh dong lan  42 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 6], [7, 5, 8]]
# hanh dong lan  43 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 5, 6], [7, 0, 8]]
# hanh dong lan  44 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 6], [7, 5, 8]]
# hanh dong lan  45 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 0], [7, 5, 8]]
# hanh dong lan  46 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 8], [7, 5, 0]]
# hanh dong lan  47 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 8], [7, 0, 5]]
# hanh dong lan  48 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 8], [7, 5, 0]]
# hanh dong lan  49 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 8], [7, 0, 5]]
# hanh dong lan  50 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 8], [7, 6, 5]]
# hanh dong lan  51 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 8, 0], [7, 6, 5]]
# hanh dong lan  52 : di len
# ma tran sau khi di chuyen:  [[1, 2, 0], [4, 8, 3], [7, 6, 5]]
# hanh dong lan  53 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 8, 0], [7, 6, 5]]
# hanh dong lan  54 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 8, 5], [7, 6, 0]]
# hanh dong lan  55 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 8, 0], [7, 6, 5]]
# hanh dong lan  56 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 8], [7, 6, 5]]
# hanh dong lan  57 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 8], [7, 0, 5]]
# hanh dong lan  58 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 8], [7, 6, 5]]
# hanh dong lan  59 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 8, 0], [7, 6, 5]]
# hanh dong lan  60 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 8], [7, 6, 5]]
# hanh dong lan  61 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 8], [7, 0, 5]]
# hanh dong lan  62 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 8], [7, 6, 5]]
# hanh dong lan  63 : di len
# ma tran sau khi di chuyen:  [[1, 0, 3], [4, 2, 8], [7, 6, 5]]
# hanh dong lan  64 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 8], [7, 6, 5]]
# hanh dong lan  65 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 4, 8], [7, 6, 5]]
# hanh dong lan  66 : di len
# ma tran sau khi di chuyen:  [[0, 2, 3], [1, 4, 8], [7, 6, 5]]
# hanh dong lan  67 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 4, 8], [7, 6, 5]]
# hanh dong lan  68 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 8], [7, 6, 5]]
# hanh dong lan  69 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 8], [7, 0, 5]]
# hanh dong lan  70 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 8], [7, 5, 0]]
# hanh dong lan  71 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 8], [7, 0, 5]]
# hanh dong lan  72 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 8], [7, 5, 0]]
# hanh dong lan  73 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 0], [7, 5, 8]]
# hanh dong lan  74 : di len
# ma tran sau khi di chuyen:  [[1, 2, 0], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  75 : di trai
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  76 : di trai
# ma tran sau khi di chuyen:  [[0, 1, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  77 : di phai
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  78 : di xuong
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 0, 3], [7, 5, 8]]
# hanh dong lan  79 : di xuong
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 5, 3], [7, 0, 8]]
# hanh dong lan  80 : di len
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 0, 3], [7, 5, 8]]
# hanh dong lan  81 : di phai
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 3, 0], [7, 5, 8]]
# hanh dong lan  82 : di len
# ma tran sau khi di chuyen:  [[1, 6, 0], [4, 3, 2], [7, 5, 8]]
# hanh dong lan  83 : di trai
# ma tran sau khi di chuyen:  [[1, 0, 6], [4, 3, 2], [7, 5, 8]]
# hanh dong lan  84 : di trai
# ma tran sau khi di chuyen:  [[0, 1, 6], [4, 3, 2], [7, 5, 8]]
# hanh dong lan  85 : di xuong
# ma tran sau khi di chuyen:  [[4, 1, 6], [0, 3, 2], [7, 5, 8]]
# hanh dong lan  86 : di phai
# ma tran sau khi di chuyen:  [[4, 1, 6], [3, 0, 2], [7, 5, 8]]
# hanh dong lan  87 : di trai
# ma tran sau khi di chuyen:  [[4, 1, 6], [0, 3, 2], [7, 5, 8]]
# hanh dong lan  88 : di xuong
# ma tran sau khi di chuyen:  [[4, 1, 6], [7, 3, 2], [0, 5, 8]]
# hanh dong lan  89 : di len
# ma tran sau khi di chuyen:  [[4, 1, 6], [0, 3, 2], [7, 5, 8]]
# hanh dong lan  90 : di phai
# ma tran sau khi di chuyen:  [[4, 1, 6], [3, 0, 2], [7, 5, 8]]
# hanh dong lan  91 : di phai
# ma tran sau khi di chuyen:  [[4, 1, 6], [3, 2, 0], [7, 5, 8]]
# hanh dong lan  92 : di trai
# ma tran sau khi di chuyen:  [[4, 1, 6], [3, 0, 2], [7, 5, 8]]
# hanh dong lan  93 : di trai
# ma tran sau khi di chuyen:  [[4, 1, 6], [0, 3, 2], [7, 5, 8]]
# hanh dong lan  94 : di xuong
# ma tran sau khi di chuyen:  [[4, 1, 6], [7, 3, 2], [0, 5, 8]]
# hanh dong lan  95 : di len
# ma tran sau khi di chuyen:  [[4, 1, 6], [0, 3, 2], [7, 5, 8]]
# hanh dong lan  96 : di len
# ma tran sau khi di chuyen:  [[0, 1, 6], [4, 3, 2], [7, 5, 8]]
# hanh dong lan  97 : di phai
# ma tran sau khi di chuyen:  [[1, 0, 6], [4, 3, 2], [7, 5, 8]]
# hanh dong lan  98 : di xuong
# ma tran sau khi di chuyen:  [[1, 3, 6], [4, 0, 2], [7, 5, 8]]
# hanh dong lan  99 : di xuong
# ma tran sau khi di chuyen:  [[1, 3, 6], [4, 5, 2], [7, 0, 8]]
# hanh dong lan  100 : di len
# ma tran sau khi di chuyen:  [[1, 3, 6], [4, 0, 2], [7, 5, 8]]
# Da dat toi so lan cho phep, ket thuc chuong trinh

# %%
import random
def tim_o_trong(ma_tran):
    for i in range(3):
        for j in range(3):
            if ma_tran[i][j] == 0:
                return i, j
def luat(x, y):
    if x == 0 and y == 0:
        return ["phai", "xuong"]
    elif x == 1 and y == 0:
        return ["len", "phai", "xuong"]
    elif x == 2 and y == 0:
        return ["len", "phai"]
    elif x == 0 and y == 1:
        return ["trai", "phai", "xuong"]
    elif x == 1 and y == 1:
        return ["len", "xuong", "trai", "phai"]
    elif x == 2 and y == 1:
        return ["len", "trai", "phai"]
    elif x == 1 and y == 2:
        return ["len", "trai", "xuong"]
    elif x == 0 and y == 2:
        return ["trai", "xuong"]
    elif x == 2 and y == 2:
        return ["len", "trai"]
def action(ma_tran):
    x, y = tim_o_trong(ma_tran)
    hanh_dong = luat(x, y)
    return random.choice(hanh_dong)

MA_TRAN = [
    [1,2,3],
    [4,5,6],
    [0,7,8]
]
SO_LAN = 0
(x, y) = tim_o_trong(MA_TRAN)
HUONG_DI = action(MA_TRAN)
print("hanh dong : di", HUONG_DI)
if(HUONG_DI == "len"):
    MA_TRAN[x][y], MA_TRAN[x-1][y] = MA_TRAN[x-1][y], MA_TRAN[x][y]
elif(HUONG_DI == "xuong"):
    MA_TRAN[x][y], MA_TRAN[x+1][y] = MA_TRAN[x+1][y], MA_TRAN[x][y]
elif(HUONG_DI == "trai"):     
    MA_TRAN[x][y], MA_TRAN[x][y-1] = MA_TRAN[x][y-1], MA_TRAN[x][y]
elif(HUONG_DI == "phai"):    
    MA_TRAN[x][y], MA_TRAN[x][y+1] = MA_TRAN[x][y+1], MA_TRAN[x][y]
print("ma tran sau khi di chuyen: ", MA_TRAN)
# Out:
# hanh dong : di  len
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 5, 6], [4, 7, 8]]
