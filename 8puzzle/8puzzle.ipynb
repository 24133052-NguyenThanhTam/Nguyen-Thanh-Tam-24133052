# %%
import random
def tim_o_trong(ma_tran):
    for i in range(3):
        for j in range(3):
            if ma_tran[i][j] == 0:
                return i, j
def luat(x, y):
    if x == 0 and y == 0:
        return ["phai", "xuong"]
    elif x == 1 and y == 0:
        return ["len", "phai", "xuong"]
    elif x == 2 and y == 0:
        return ["len", "phai"]
    elif x == 0 and y == 1:
        return ["trai", "phai", "xuong"]
    elif x == 1 and y == 1:
        return ["len", "xuong", "trai", "phai"]
    elif x == 2 and y == 1:
        return ["len", "trai", "phai"]
    elif x == 1 and y == 2:
        return ["len", "trai", "xuong"]
    elif x == 0 and y == 2:
        return ["trai", "xuong"]
    elif x == 2 and y == 2:
        return ["len", "trai"]
def action(ma_tran):
    x, y = tim_o_trong(ma_tran)
    hanh_dong = luat(x, y)
    return random.choice(hanh_dong)

MA_TRAN = [
    [1,2,3],
    [4,5,6],
    [0,7,8]
]
KETQUA = [
    [1,2,3],
    [4,5,6],
    [7,8,0]
]
SO_LAN = 0
while ((MA_TRAN != KETQUA) and (SO_LAN < 100)):
    SO_LAN += 1
    (x, y) = tim_o_trong(MA_TRAN)
    HUONG_DI = action(MA_TRAN)
    print("hanh dong lan ",SO_LAN, ": di", HUONG_DI)
    if(HUONG_DI == "len"):
        MA_TRAN[x][y], MA_TRAN[x-1][y] = MA_TRAN[x-1][y], MA_TRAN[x][y]
    elif(HUONG_DI == "xuong"):
            MA_TRAN[x][y], MA_TRAN[x+1][y] = MA_TRAN[x+1][y], MA_TRAN[x][y]
    elif(HUONG_DI == "trai"):     
        MA_TRAN[x][y], MA_TRAN[x][y-1] = MA_TRAN[x][y-1], MA_TRAN[x][y]
    elif(HUONG_DI == "phai"):    
        MA_TRAN[x][y], MA_TRAN[x][y+1] = MA_TRAN[x][y+1], MA_TRAN[x][y]
    print("ma tran sau khi di chuyen: ", MA_TRAN)
    if(SO_LAN == 100):
        print("Da dat toi so lan cho phep, ket thuc chuong trinh")
# Out:
# hanh dong lan  1 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 5, 6], [7, 0, 8]]
# hanh dong lan  2 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 6], [7, 5, 8]]
# hanh dong lan  3 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 0], [7, 5, 8]]
# hanh dong lan  4 : di len
# ma tran sau khi di chuyen:  [[1, 2, 0], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  5 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 0], [7, 5, 8]]
# hanh dong lan  6 : di len
# ma tran sau khi di chuyen:  [[1, 2, 0], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  7 : di trai
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  8 : di xuong
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 0, 3], [7, 5, 8]]
# hanh dong lan  9 : di len
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  10 : di xuong
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 0, 3], [7, 5, 8]]
# hanh dong lan  11 : di phai
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 3, 0], [7, 5, 8]]
# hanh dong lan  12 : di len
# ma tran sau khi di chuyen:  [[1, 6, 0], [4, 3, 2], [7, 5, 8]]
# hanh dong lan  13 : di trai
# ma tran sau khi di chuyen:  [[1, 0, 6], [4, 3, 2], [7, 5, 8]]
# hanh dong lan  14 : di phai
# ma tran sau khi di chuyen:  [[1, 6, 0], [4, 3, 2], [7, 5, 8]]
# hanh dong lan  15 : di xuong
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 3, 0], [7, 5, 8]]
# hanh dong lan  16 : di trai
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 0, 3], [7, 5, 8]]
# hanh dong lan  17 : di trai
# ma tran sau khi di chuyen:  [[1, 6, 2], [0, 4, 3], [7, 5, 8]]
# hanh dong lan  18 : di phai
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 0, 3], [7, 5, 8]]
# hanh dong lan  19 : di trai
# ma tran sau khi di chuyen:  [[1, 6, 2], [0, 4, 3], [7, 5, 8]]
# hanh dong lan  20 : di phai
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 0, 3], [7, 5, 8]]
# hanh dong lan  21 : di len
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  22 : di trai
# ma tran sau khi di chuyen:  [[0, 1, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  23 : di xuong
# ma tran sau khi di chuyen:  [[4, 1, 2], [0, 6, 3], [7, 5, 8]]
# hanh dong lan  24 : di len
# ma tran sau khi di chuyen:  [[0, 1, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  25 : di phai
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  26 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 0], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  27 : di trai
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  28 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 0], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  29 : di trai
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  30 : di trai
# ma tran sau khi di chuyen:  [[0, 1, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  31 : di xuong
# ma tran sau khi di chuyen:  [[4, 1, 2], [0, 6, 3], [7, 5, 8]]
# hanh dong lan  32 : di len
# ma tran sau khi di chuyen:  [[0, 1, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  33 : di xuong
# ma tran sau khi di chuyen:  [[4, 1, 2], [0, 6, 3], [7, 5, 8]]
# hanh dong lan  34 : di len
# ma tran sau khi di chuyen:  [[0, 1, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  35 : di xuong
# ma tran sau khi di chuyen:  [[4, 1, 2], [0, 6, 3], [7, 5, 8]]
# hanh dong lan  36 : di len
# ma tran sau khi di chuyen:  [[0, 1, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  37 : di xuong
# ma tran sau khi di chuyen:  [[4, 1, 2], [0, 6, 3], [7, 5, 8]]
# hanh dong lan  38 : di len
# ma tran sau khi di chuyen:  [[0, 1, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  39 : di phai
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  40 : di trai
# ma tran sau khi di chuyen:  [[0, 1, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  41 : di phai
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  42 : di trai
# ma tran sau khi di chuyen:  [[0, 1, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  43 : di phai
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  44 : di xuong
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 0, 3], [7, 5, 8]]
# hanh dong lan  45 : di phai
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 3, 0], [7, 5, 8]]
# hanh dong lan  46 : di trai
# ma tran sau khi di chuyen:  [[1, 6, 2], [4, 0, 3], [7, 5, 8]]
# hanh dong lan  47 : di len
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  48 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 0], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  49 : di trai
# ma tran sau khi di chuyen:  [[1, 0, 2], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  50 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 0], [4, 6, 3], [7, 5, 8]]
# hanh dong lan  51 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 0], [7, 5, 8]]
# hanh dong lan  52 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 8], [7, 5, 0]]
# hanh dong lan  53 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 6, 8], [7, 0, 5]]
# hanh dong lan  54 : di len
# ma tran sau khi di chuyen:  [[1, 2, 3], [4, 0, 8], [7, 6, 5]]
# hanh dong lan  55 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 4, 8], [7, 6, 5]]
# hanh dong lan  56 : di len
# ma tran sau khi di chuyen:  [[0, 2, 3], [1, 4, 8], [7, 6, 5]]
# hanh dong lan  57 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 4, 8], [7, 6, 5]]
# hanh dong lan  58 : di len
# ma tran sau khi di chuyen:  [[0, 2, 3], [1, 4, 8], [7, 6, 5]]
# hanh dong lan  59 : di phai
# ma tran sau khi di chuyen:  [[2, 0, 3], [1, 4, 8], [7, 6, 5]]
# hanh dong lan  60 : di trai
# ma tran sau khi di chuyen:  [[0, 2, 3], [1, 4, 8], [7, 6, 5]]
# hanh dong lan  61 : di phai
# ma tran sau khi di chuyen:  [[2, 0, 3], [1, 4, 8], [7, 6, 5]]
# hanh dong lan  62 : di phai
# ma tran sau khi di chuyen:  [[2, 3, 0], [1, 4, 8], [7, 6, 5]]
# hanh dong lan  63 : di xuong
# ma tran sau khi di chuyen:  [[2, 3, 8], [1, 4, 0], [7, 6, 5]]
# hanh dong lan  64 : di trai
# ma tran sau khi di chuyen:  [[2, 3, 8], [1, 0, 4], [7, 6, 5]]
# hanh dong lan  65 : di len
# ma tran sau khi di chuyen:  [[2, 0, 8], [1, 3, 4], [7, 6, 5]]
# hanh dong lan  66 : di trai
# ma tran sau khi di chuyen:  [[0, 2, 8], [1, 3, 4], [7, 6, 5]]
# hanh dong lan  67 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 8], [0, 3, 4], [7, 6, 5]]
# hanh dong lan  68 : di len
# ma tran sau khi di chuyen:  [[0, 2, 8], [1, 3, 4], [7, 6, 5]]
# hanh dong lan  69 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 8], [0, 3, 4], [7, 6, 5]]
# hanh dong lan  70 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 0, 4], [7, 6, 5]]
# hanh dong lan  71 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 4], [7, 0, 5]]
# hanh dong lan  72 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 4], [7, 5, 0]]
# hanh dong lan  73 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 4], [7, 0, 5]]
# hanh dong lan  74 : di len
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 0, 4], [7, 6, 5]]
# hanh dong lan  75 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 4], [7, 0, 5]]
# hanh dong lan  76 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 4], [0, 7, 5]]
# hanh dong lan  77 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 4], [7, 0, 5]]
# hanh dong lan  78 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 4], [0, 7, 5]]
# hanh dong lan  79 : di len
# ma tran sau khi di chuyen:  [[1, 2, 8], [0, 6, 4], [3, 7, 5]]
# hanh dong lan  80 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 4], [0, 7, 5]]
# hanh dong lan  81 : di len
# ma tran sau khi di chuyen:  [[1, 2, 8], [0, 6, 4], [3, 7, 5]]
# hanh dong lan  82 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 4], [0, 7, 5]]
# hanh dong lan  83 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 4], [7, 0, 5]]
# hanh dong lan  84 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 4], [7, 5, 0]]
# hanh dong lan  85 : di len
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 0], [7, 5, 4]]
# hanh dong lan  86 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 0, 6], [7, 5, 4]]
# hanh dong lan  87 : di phai
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 0], [7, 5, 4]]
# hanh dong lan  88 : di len
# ma tran sau khi di chuyen:  [[1, 2, 0], [3, 6, 8], [7, 5, 4]]
# hanh dong lan  89 : di xuong
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 6, 0], [7, 5, 4]]
# hanh dong lan  90 : di trai
# ma tran sau khi di chuyen:  [[1, 2, 8], [3, 0, 6], [7, 5, 4]]
# hanh dong lan  91 : di len
# ma tran sau khi di chuyen:  [[1, 0, 8], [3, 2, 6], [7, 5, 4]]
# hanh dong lan  92 : di trai
# ma tran sau khi di chuyen:  [[0, 1, 8], [3, 2, 6], [7, 5, 4]]
# hanh dong lan  93 : di phai
# ma tran sau khi di chuyen:  [[1, 0, 8], [3, 2, 6], [7, 5, 4]]
# hanh dong lan  94 : di trai
# ma tran sau khi di chuyen:  [[0, 1, 8], [3, 2, 6], [7, 5, 4]]
# hanh dong lan  95 : di xuong
# ma tran sau khi di chuyen:  [[3, 1, 8], [0, 2, 6], [7, 5, 4]]
# hanh dong lan  96 : di xuong
# ma tran sau khi di chuyen:  [[3, 1, 8], [7, 2, 6], [0, 5, 4]]
# hanh dong lan  97 : di len
# ma tran sau khi di chuyen:  [[3, 1, 8], [0, 2, 6], [7, 5, 4]]
# hanh dong lan  98 : di len
# ma tran sau khi di chuyen:  [[0, 1, 8], [3, 2, 6], [7, 5, 4]]
# hanh dong lan  99 : di phai
# ma tran sau khi di chuyen:  [[1, 0, 8], [3, 2, 6], [7, 5, 4]]
# hanh dong lan  100 : di phai
# ma tran sau khi di chuyen:  [[1, 8, 0], [3, 2, 6], [7, 5, 4]]
# Da dat toi so lan cho phep, ket thuc chuong trinh

# %%
import random
def tim_o_trong(ma_tran):
    for i in range(3):
        for j in range(3):
            if ma_tran[i][j] == 0:
                return i, j
def luat(x, y):
    if x == 0 and y == 0:
        return ["phai", "xuong"]
    elif x == 1 and y == 0:
        return ["len", "phai", "xuong"]
    elif x == 2 and y == 0:
        return ["len", "phai"]
    elif x == 0 and y == 1:
        return ["trai", "phai", "xuong"]
    elif x == 1 and y == 1:
        return ["len", "xuong", "trai", "phai"]
    elif x == 2 and y == 1:
        return ["len", "trai", "phai"]
    elif x == 1 and y == 2:
        return ["len", "trai", "xuong"]
    elif x == 0 and y == 2:
        return ["trai", "xuong"]
    elif x == 2 and y == 2:
        return ["len", "trai"]
def action(ma_tran):
    x, y = tim_o_trong(ma_tran)
    hanh_dong = luat(x, y)
    return random.choice(hanh_dong)

MA_TRAN = [
    [1,2,3],
    [4,5,6],
    [0,7,8]
]
SO_LAN = 0
(x, y) = tim_o_trong(MA_TRAN)
HUONG_DI = action(MA_TRAN)
print("hanh dong : di", HUONG_DI)
if(HUONG_DI == "len"):
    MA_TRAN[x][y], MA_TRAN[x-1][y] = MA_TRAN[x-1][y], MA_TRAN[x][y]
elif(HUONG_DI == "xuong"):
    MA_TRAN[x][y], MA_TRAN[x+1][y] = MA_TRAN[x+1][y], MA_TRAN[x][y]
elif(HUONG_DI == "trai"):     
    MA_TRAN[x][y], MA_TRAN[x][y-1] = MA_TRAN[x][y-1], MA_TRAN[x][y]
elif(HUONG_DI == "phai"):    
    MA_TRAN[x][y], MA_TRAN[x][y+1] = MA_TRAN[x][y+1], MA_TRAN[x][y]
print("ma tran sau khi di chuyen: ", MA_TRAN)
# Out:
# hanh dong : di  len
# ma tran sau khi di chuyen:  [[1, 2, 3], [0, 5, 6], [4, 7, 8]]
